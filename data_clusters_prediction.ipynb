# %% [markdown]
# ## Clusters

# %%
import seaborn as sn
sns.scatterplot(x='PCA1',y='PCA2',hue='Cluster',data=df,palette='viridis', s=100, edgecolor='k')
plt.show()

# %% [markdown]
# ## Predictions

# %%
# n_components must be between 0 and min(n_samples, n_features) 

z=[[1,23,12,60],
   [0,23,15,70]]

# %%
pc=PCA(n_components=2)
Z=pc.fit_transform(z)
pred=kmeans.predict(Z)
print('The customers are in cluster : ',pred)
# Out:
# The customers are in cluster :  [1 1]

# %% [markdown]
# ## Properties of Clusters

# %%
# Plot boxplot of Age for all clusters
plt.figure(figsize=(10, 6))
sns.boxplot(x='Cluster', y='Age', data=df)
plt.title('Boxplot of Age by Cluster')
plt.xlabel('Cluster')
plt.ylabel('Age')
plt.show()

# %%
# Plot boxplot of Annual Income for all clusters
plt.figure(figsize=(10, 6))
sns.boxplot(x='Cluster', y='Annual Income (k$)', data=df)
plt.title('Boxplot of Annual Income by Cluster')
plt.xlabel('Cluster')
plt.ylabel('Annual Income (k$)')
plt.show()

# %%
# Plot boxplot of Spending Score for all clusters
plt.figure(figsize=(10, 6))
sns.boxplot(x='Cluster', y='Spending Score (1-100)', data=df)
plt.title('Boxplot of Spending Score by Cluster')
plt.xlabel('Cluster')
plt.ylabel('Spending Score (1-100)')
plt.show()

# %%
# Scatter plot of Age vs. Annual Income for Cluster 0
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Age', y='Annual Income (k$)', data=df, hue='Cluster',s=100, palette='viridis')
plt.title('Age vs. Annual Income for Clusters')
plt.xlabel('Age')
plt.ylabel('Annual Income (k$)')
plt.legend(title='Cluster')
plt.show()
